# %% [markdown]
# # Analysis
#
# For each query specified in the assignment, compute the answers. Include a plot of
# these results in this notebook. Briefly discuss what you can observe from these results. Beware that for some queries, not all of the sub-dataset types have the information required to answer the query. In that case, please ignore those sub-datasets

# %%
# Imports go here
import os
import glob
import pandas as pd
import os 
import shutil
import datetime
import numpy as np
import geopandas as gpd
from datetime import date
from datetime import datetime, timedelta
from pyspark.sql.functions import col, lit
import pyspark.sql.functions as f
from pyspark.sql.functions import hour, mean
from shutil import copyfile
from shapely.geometry import Point
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.dates as mdates
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
os.environ['PYSPARK_SUBMIT_ARGS'] ="--conf spark.driver.memory=3g  pyspark-shell"
from pyspark.sql import SparkSession
try: 
    spark
    print("Spark application already started. Terminating existing application and starting new one")
    spark.stop()
except: 
    pass
# Create a new spark session (note, the * indicates to use all available CPU cores)
spark = SparkSession \
    .builder \
    .master("local[*]") \
    .appName("H600 L-Group") \
    .getOrCreate()
#When dealing with RDDs, we work the sparkContext object. See https://spark.apache.org/docs/latest/api/python/pyspark.html#pyspark.SparkContext
sc=spark.sparkContext
#in local mode, you will be able to access the Spark GUI at http://localhost:4040

# %% [markdown]
# ## Declaration of usefull functions and parameters

# %%
## FUNCTION DECLARATION
# Creation of a function to convert lat-lon into location ID
def convertlocID(lon, lat):
    """
    This function define the location ID from the latitude and longitude coordinates.
    It assumes that the files taxis_zones.shp is already loaded and converted unsing the epsg 4326 projection.
    
    Input: the latitude and longitude.      
    Output: the locationID deduce from GPS positions.
    """  
    global locationID # access the outer scope variable by declaring it global
    if lon != None and lat != None and lon < -73.0 and lon > -75.0 and lat > 40.0 and lat < 42.0:
        query_point = Point( lon, lat)
        possible_matches = list(rtree.intersection( query_point.bounds ))
        for i in range(0,len(possible_matches)) :
            if zones.iloc[possible_matches[i]].geometry.contains(query_point) == True :
                locationID = possible_matches[i]
    else:
        locationID = 9999
    
    return locationID

# Check if the value is null or not
def blank_as_null(x):
    """
    This function define blank as null in order to be more easily interpreted.
    
    Input: the column name that need to be check      
    Output: the column corrected
    """  
    return f.when(col(x).isNull(), 0 ).otherwise(col(x))

def create_files_list(path, brand, list_files):
    """
    This function create the files list of specify taxi brand (brand) from the specify folder (path). 
    
    Input: the path where are the files -> /data/cleaned or data/sampled
           the name of the taxi company -> fhv, fhvfh, green, yellow
           the empty file name list in which each file will be append
    Output: number of files in the list and the list of files name.
    """  
    global nb_files
    nb_files = 0
    for file in glob.glob("%s/%s_*.csv" %(path,brand)):
        nb_files = nb_files+1
        # Save in list the files name
        list_files.append(file)
        # Order by date the file list
        list_files.sort()

    return list_files, nb_files

def get_locID_fromzone(x,zone_name) :
    """
    This function look for particular regions in the dateframe and save the list of location ID
    
    Input: the dataframe (x) and the location name (zone_name).      
    Output: the locationID of for this name.
    """  
    locID = x.where((col("borough") == zone_name) ).select(col("LocationID"))
    locID = [row[0] for row in locID.select("LocationID").collect()]

    return locID  

def create_date_range(yr,mth) :
    """
    This function provide the datetime var of the 1st day and a datetime var 
    for the last day of the same month for on a specific year.
    
    Input: the year and the month     
    Output: date1 for 1st day of the month
            date2 for last day of the month
    """  
    end_mth = mth + 1
    date1=pd.to_datetime('%s-%s-01 00:00:00' %(yr,mth))
    if end_mth == 13 :
        date2=pd.to_datetime('%s-12-31 00:00:00' %(yr))
    else :
        date2=pd.to_datetime('%s-%s-01 00:00:00' %(yr,end_mth))
    
    return date1, date2

def convert_sec_to_min(sec):
    """
    This function provide convert unix timestamp from seconde to minute
    
    Input: unix timestamp in sec  
    Output: numbers of minutes  
    """  
    sec_value = sec % (24 * 3600)
    sec_value %= 3600
    min = sec_value / 60
    
    return min



def calculate_bounds(df):
    bounds = {
        c: dict(
            zip(["q1", "q3"], df.approxQuantile(c, [0.01, 0.99], 0))
        )
        for c,d in zip(df.columns, df.dtypes) if d[1] == "double"
    }

    for c in bounds:
        iqr = bounds[c]['q3'] - bounds[c]['q1']
        bounds[c]['min'] = bounds[c]['q1'] - (iqr * 1.5)
        bounds[c]['max'] = bounds[c]['q3'] + (iqr * 1.5)

    return bounds


## PARAMETERS DECLARATION
cl_path = "data/cleaned/"

## PLOT PARAMETERS
parameters = {'axes.labelsize': 25,
          'axes.titlesize': 35,
          'legend.fontsize': 20,
          'xtick.labelsize': 20,
          'ytick.labelsize':20}
plt.rcParams.update(parameters)

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y') # xlabel only the year

# To get color list
overlap = {name for name in mcolors.CSS4_COLORS if "xkcd:" + name in mcolors.XKCD_COLORS}

# Create date frame from the time axis
rng = pd.date_range('2008-06-15', periods=13*12, freq='m')
xmin = rng[0]
xmax = rng[-1]

# %% [markdown]
# ## 1. Taxis companies popularity
#
# How the popularity of a particular service (Yellow Taxi, Green Taxi, FHV, FHVHV) is evolving over time?
#
# ##### Method:
# Look at in the clean file of all the Taxi compagnies the numers of trips within a month. We firstly create a list of avail year in each data set (list_year) and then filter the data sets to extract the montlhy mean of each year (var_pop).
#
# ##### Conclusion:
# From the figure above, we can see that for the Yellow taxi compagny, even if there are montlhy variations in the number of trips, between 2009 and begining of 2012 the number of trips slightly increased. From there on, the number of trips with the Yellow taxi started to decrease. These lower numbers of monthly trips were amplified in beginning of 2014, when the Green taxi compagny appeared on the market. Starting in 2015, and in less than 4 years, the montlhy number of trips of the FHV taxis compagnies exploded to reach a bit less than 50 000 monthly trips. In the mean time, the Yellow taxi compagny pursued its decline. Regarding the Green compagny taxi, after a plateau of around 3000 monthly trips, the decline of its numbers followed the explosion of the FHV trips. In 2019, FHV compagnies were slipt in High Volume FHV (called on the plot FHVHV) and others FHV compagnies doing fewer daily trips. This split explains the big drop in January 2019. From 2019, the FHV and FHVHV had stable monthly number of trips, until the COVID-19 appeared in March 2020. The effect is a an abrupt decrease of the number of trip for all the Taxi compagnies. Then in April 2020, the number of trips for all taxi compagnies seems to increase again, but need to be confirmed over the next months.
#
#
# ![Figure 1](data/Plot_Q1_popularity_allTAXI.png)

# %%
# Get the numbers of trips by months for each taxi compagnies
list_taxi = ["fhv","fhvhv", "yellow", "green"]
#list_year = {}
#dating = {}
#var_pop = {}
maxi = 0
for taxi_brand in list_taxi :
    print(taxi_brand)
    list_year[taxi_brand] = []
    var_pop[taxi_brand] = []
    dating[taxi_brand] = []
    # Get the list of the file for each taxi
    DF = (spark.read
                    .option("sep", ",")
                    .option("header", True)
                    .option("inferSchema", True)
                    .csv(cl_path+taxi_brand+"/*.csv") )
    # Get the date of each lines and get the list of years
    DF = DF.orderBy("pickup_datetime")
    year_extract = DF.selectExpr("year(pickup_datetime) AS year", "pickup_datetime").groupBy("year").sum().orderBy("year").select("year")
    list_year[taxi_brand] = [row[0] for row in year_extract.select('year').collect()]
    # For each years of the files, compute the monthly sum of the trips
    for yr in list_year[taxi_brand] :
        for mth in range(1,13,1):
            print(yr,mth)
            date1, date2 = create_date_range(yr,mth)
            test = DF.filter(col("pickup_datetime").between(date1,date2))\
                                    .select(f.count(col("pickup_datetime")))\
                                    .withColumn("count(pickup_datetime)", f.when(col("count(pickup_datetime)") == 0, None).otherwise(col("count(pickup_datetime)")))\
                                    .collect()
            var_pop[taxi_brand].append([row[0] for row in test])
            #maxi = max(maxi,max(var[taxi_brand])[0])
            dating[taxi_brand].append(date1+timedelta(days=14))
# Out:
# fhvhv
# 2019 1
# 2019 2
# 2019 3
# 2019 4
# 2019 5
# 2019 6
# 2019 7
# 2019 8
# 2019 9
# 2019 10
# 2019 11
# 2019 12
# 2020 1
# 2020 2
# 2020 3
# 2020 4
# 2020 5
# 2020 6
# 2020 7
# 2020 8
# 2020 9
# 2020 10
# 2020 11
# 2020 12
# yellow
# 2009 1
# 2009 2
# 2009 3
# 2009 4
# 2009 5
# 2009 6
# 2009 7
# 2009 8
# 2009 9
# 2009 10
# 2009 11
# 2009 12
# 2010 1
# 2010 2
# 2010 3
# 2010 4
# 2010 5
# 2010 6
# 2010 7
# 2010 8
# 2010 9
# 2010 10
# 2010 11
# 2010 12
# 2011 1
# 2011 2
# 2011 3
# 2011 4
# 2011 5
# 2011 6
# 2011 7
# 2011 8
# 2011 9
# 2011 10
# 2011 11
# 2011 12
# 2012 1
# 2012 2
# 2012 3
# 2012 4
# 2012 5
# 2012 6
# 2012 7
# 2012 8
# 2012 9
# 2012 10
# 2012 11
# 2012 12
# 2013 1
# 2013 2
# 2013 3
# 2013 4
# 2013 5
# 2013 6
# 2013 7
# 2013 8
# 2013 9
# 2013 10
# 2013 11
# 2013 12
# 2014 1
# 2014 2
# 2014 3
# 2014 4
# 2014 5
# 2014 6
# 2014 7
# 2014 8
# 2014 9
# 2014 10
# 2014 11
# 2014 12
# 2015 1
# 2015 2
# 2015 3
# 2015 4
# 2015 5
# 2015 6
# 2015 7
# 2015 8
# 2015 9
# 2015 10
# ...

# %%
list_taxi = ["fhv","fhvhv", "yellow", "green"]
# Plot the numbers of monthly number of trips 
i = 0
fig, ax = plt.subplots(1,figsize=(12,7))
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(years_fmt)
ax.xaxis.set_minor_locator(months)
for taxi_brand in list_taxi :
    i = i+6
    colors = (sorted(overlap,reverse=True))[i]
    ax.plot(dating[taxi_brand],var_pop[taxi_brand],color=colors,label='%s taxi' %(taxi_brand),lw=3) # Line not visible, only to show values
ax.set_xlim(xmin,xmax,1)
ax.set_ylim(0,60000)
ax.set_xlabel("Time")
ax.set_ylabel("Numbers of trips by month")
ax.format_ydata = lambda x: '$%1.2f' % x
ax.grid(True)
plt.legend(ncol=2,loc=2)
fig.autofmt_xdate()
plt.savefig(cl_path+"../Plot_Q1_popularity_allTAXI.png", bbox_inches = 'tight', pad_inches=0)

# %% [markdown]
# ## 2. Taxis companies popularity in Manhattan and Brooklyn.
#
# How the popularity of a particular service (Yellow Taxi, Green Taxi, FHV, FHVHV) is evolving over time in Manhattan and Brooklyn?
#
# ##### Method:
# Look at in the clean file of all the Taxi compagnies the numers of trips within a month occuring in the Manhattan and Brooklyn zones. We firstly select trips that are in the zones using their respectiv location ID. Then we create a list of avail year for these selected trips (list_year) and then filter the data sets to extract the montlhy mean of each year (var_pop) and for each zones.
#
# ##### Conclusion:
# At first sight, we can see that the Manhattan and Brooklyn zones represent almost half of the total number of trips in New-York (compared to Figure in question 1). By comparing both zones, the number of trips in Manhattan is around the double as the number of trips in Brooklyn. Regarding the trends, they are similar as the description of the Figure in question 1. The difference is only on the total number of trips.
#
#
#
# ![Figure 2](data/Plot_Q2_popularity_allTAXI_Man-Br.png)

# %%
# Load the shapefile, this yields a GeoDataFrame that has a row for each zone
zones = gpd.read_file('data/metadata/taxi_zones.shp')
zones_df = spark.createDataFrame(zones).cache()

list_taxi = ["fhv", "fhvhv", "yellow", "green"]
list_year = {}
dating = {}
var_pop_MB = {}
maxi = 0
for taxi_brand in list_taxi :
    # Get the list of the file for each taxi
    DF = (spark.read
                    .option("sep", ",")
                    .option("header", True)
                    .option("inferSchema", True)
                    .csv(cl_path+taxi_brand+"/*.csv") )
    print(DF.printSchema())
    for zones in ["Manhattan" , "Brooklyn"] :
        var_name = taxi_brand+"-"+zones
        print(var_name)
        list_year[var_name] = []
        dating[var_name] = []
        var_pop_MB[var_name] = []
        # LocationID for Manhattan
        locID = get_locID_fromzone(zones_df, zones)
        select_zone = DF.where(col("pulocationid").isin(locID)).select(col("pickup_datetime"))
        # Get the date of each lines and get the list of years
        select_zone = select_zone.orderBy("pickup_datetime")
        year_extract = select_zone.selectExpr("year(pickup_datetime) AS year", "pickup_datetime").groupBy("year").sum().orderBy("year").select("year")
        list_year[var_name] = [row[0] for row in year_extract.select('year').collect()]
        # For each years of the files, compute the monthly sum of the trips
        for yr in list_year[var_name] :
            for mth in range(1,13,1):
                print(yr,mth)
                date1, date2 = create_date_range(yr,mth)
                test = select_zone.filter(col("pickup_datetime").between(date1,date2))\
                                        .select(f.count(col("pickup_datetime")))\
                                        .withColumn("count(pickup_datetime)", f.when(col("count(pickup_datetime)") == 0, None).otherwise(col("count(pickup_datetime)")))
                var_pop_MB[var_name].append([row[0] for row in test.select('count(pickup_datetime)').collect()])
                #maxi = max(maxi,max(var[taxi_brand])[0])
                dating[var_name].append(date1+timedelta(days=14))
# Out:
# root
#  |-- pickup_datetime: timestamp (nullable = true)
#  |-- dropoff_datetime: timestamp (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#
# None
# fhv-Manhattan
# 2015 1
# 2015 2
# 2015 3
# 2015 4
# 2015 5
# 2015 6
# 2015 7
# 2015 8
# 2015 9
# 2015 10
# 2015 11
# 2015 12
# 2016 1
# 2016 2
# 2016 3
# 2016 4
# 2016 5
# 2016 6
# 2016 7
# 2016 8
# 2016 9
# 2016 10
# 2016 11
# 2016 12
# 2017 1
# 2017 2
# 2017 3
# 2017 4
# 2017 5
# 2017 6
# 2017 7
# 2017 8
# 2017 9
# 2017 10
# 2017 11
# 2017 12
# 2018 1
# 2018 2
# 2018 3
# 2018 4
# 2018 5
# 2018 6
# 2018 7
# 2018 8
# 2018 9
# 2018 10
# 2018 11
# 2018 12
# 2019 1
# 2019 2
# 2019 3
# 2019 4
# 2019 5
# 2019 6
# 2019 7
# 2019 8
# 2019 9
# 2019 10
# 2019 11
# 2019 12
# 2020 1
# 2020 2
# 2020 3
# 2020 4
# 2020 5
# 2020 6
# 2020 7
# 2020 8
# 2020 9
# 2020 10
# 2020 11
# 2020 12
# fhv-Brooklyn
# 2015 1
# 2015 2
# 2015 3
# 2015 4
# 2015 5
# 2015 6
# 2015 7
# 2015 8
# 2015 9
# 2015 10
# 2015 11
# 2015 12
# 2016 1
# 2016 2
# ...

# %%
# Plot the numbers of monthly number of trips 
parameters = {'axes.labelsize': 25,
          'axes.titlesize': 35,
          'legend.fontsize': 15,
          'xtick.labelsize': 20,
          'ytick.labelsize':20}
plt.rcParams.update(parameters)
i = 0
fig, ax = plt.subplots(1,figsize=(24,14))
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(years_fmt)
ax.xaxis.set_minor_locator(months)
for taxi_brand in list_taxi :
    for zones in ["Manhattan" , "Brooklyn"] :
        var_name = taxi_brand+"-"+zones
        i = i+6
        colors = (sorted(overlap,reverse=True))[i]
        ax.plot(dating[var_name],var_pop_MB[var_name],color=colors,label='%s taxi' %(var_name),lw=3) # Line not visible, only to show values
ax.set_xlim(xmin,xmax,1)
ax.set_ylim(0,60000)
ax.set_xlabel("Time")
ax.set_ylabel("Numbers of trips by month")
ax.format_ydata = lambda x: '$%1.2f' % x
ax.grid(True)
plt.legend(ncol=2,loc=2)
fig.autofmt_xdate()
plt.savefig(cl_path+"../Plot_Q2_popularity_allTAXI_Man-Br.png", bbox_inches = 'tight', pad_inches=0)

# %% [markdown]
# ## 3. Which taxi compagny  is making the highest montlhy revenue ?
#
# Which service provider between Yellow Taxi, Green Taxi, FHV and FHVHV is making the most revenue ? Revenu is the sum over all receipts in the same month of fares, surcharges, taxes and tolls. It not includes tips. Following the schema of the data we previously decide, the revenu is the total_amoumt minus the tip_amount.
#
# ##### WARNING: only Yellow and Green taxi compagnies have revenue informations.
#
# ##### Method:
# Look at in the clean file of all the Yellow and Green taxi compagnies the total amount from all trips within a month. The tip amount is not take into account here. We firstly create a list of avail year for these selected trips (list_year) and then filter the data sets to extract the montlhy sum of revenu of each year (var_sumRev).
#
# ##### Conclusion:
#
#
#
#
# ![Figure 3](data/Plot_Q3_revenu_Yell-Gre.png)

# %%
list_taxi = [ "yellow", "green"]
list_year = {}
dating_sumRev = {}
var_sumRev = {}
maxi = 0
for taxi_brand in list_taxi :
    print(taxi_brand)
    list_year[taxi_brand] = []
    var_sumRev[taxi_brand] = []
    dating_sumRev[taxi_brand] = []
    # Get the list of the file for each taxi
    DF = (spark.read
                    .option("sep", ",")
                    .option("header", True)
                    .option("inferSchema", True)
                    .csv(cl_path+taxi_brand+"/*.csv") )
    # Get the date of each lines and get the list of years
    DF = DF.withColumn("revenue", (col("total_amount") - col("tip_amount")))
    DF = DF.orderBy("pickup_datetime")
    year_extract = DF.selectExpr("year(pickup_datetime) AS year", "pickup_datetime").groupBy("year").sum().orderBy("year").select("year")
    list_year[taxi_brand] = [row[0] for row in year_extract.select('year').collect()]
    # For each years of the files, compute the monthly sum of the trips
    for yr in [2015,2016] :
        for mth in range(1,13,1):
            print(yr,mth)
            date1, date2 = create_date_range(yr,mth)
            test = DF.filter(col("pickup_datetime").between(date1,date2)).select(f.sum(col("revenue")))\
                                .withColumn("sum(revenue)", f.when(col("sum(revenue)") == 0, None).otherwise(col("sum(revenue)")))\
                                .collect()
            var_sumRev[taxi_brand].append([row[0] for row in test])
            #maxi = max(maxi,max(var[taxi_brand])[0])
            dating_sumRev[taxi_brand].append(date1+timedelta(days=14))
# Out:
# yellow
# 2015 1
# 2015 2
# 2015 3
# 2015 4
# 2015 5
# 2015 6
# 2015 7
# 2015 8
# 2015 9
# 2015 10
# 2015 11
# 2015 12
# 2016 1
# 2016 2
# 2016 3
# 2016 4
# 2016 5
# 2016 6
# 2016 7
# 2016 8
# 2016 9
# 2016 10
# 2016 11
# 2016 12
# green
# 2015 1
# 2015 2
# 2015 3
# 2015 4
# 2015 5
# 2015 6
# 2015 7
# 2015 8
# 2015 9
# 2015 10
# 2015 11
# 2015 12
# 2016 1
# 2016 2
# 2016 3
# 2016 4
# 2016 5
# 2016 6
# 2016 7
# 2016 8
# 2016 9
# 2016 10
# 2016 11
# 2016 12

# %%
# Plot the numbers of monthly number of trips 
i = 0
fig, ax = plt.subplots(1,figsize=(34,15))
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(years_fmt)
ax.xaxis.set_minor_locator(months)
for taxi_brand in ['yellow','green'] :
    ax.plot(dating[taxi_brand],var[taxi_brand],color=taxi_brand,label='%s taxi' %(taxi_brand),lw=3) # Line not visible, only to show values
ax.set_xlim(xmin,xmax,1)
ax.set_ylim(0,400000)
ax.set_xlabel("Time")
ax.set_ylabel("Total revenue by month")
ax.format_ydata = lambda x: '$%1.2f' % x
ax.grid(True)
plt.legend(ncol=4,loc=2)
fig.autofmt_xdate()
plt.savefig(cl_path+"../Plot_Q3_revenu_Yell-Gre.png", bbox_inches = 'tight', pad_inches=0)

# %% [markdown]
# ## 4. What is the montlhy average trip receipt ?
#
# The average trip receipt, where the average is computed over trips within the same month,
# grouped per taxi compagny.
#
# ##### WARNING: only Yellow and Green taxi compagnies have revenue informations.

# %%
list_taxi = [ "yellow", "green"]
list_year = {}
dating = {}
var = {}
maxi = 0
for taxi_brand in list_taxi :
    print(taxi_brand)
    list_year[taxi_brand] = []
    var[taxi_brand] = []
    dating[taxi_brand] = []
    # Get the list of the file for each taxi
    DF = (spark.read
                    .option("sep", ",")
                    .option("header", True)
                    .option("inferSchema", True)
                    .csv(cl_path+taxi_brand+"/*.csv") )
    # Get the date of each lines and get the list of years
    DF = DF.withColumn("revenue", (col("total_amount") - col("tip_amount")))
    DF = DF.orderBy("pickup_datetime")
    year_extract = DF.selectExpr("year(pickup_datetime) AS year", "pickup_datetime").groupBy("year").sum().orderBy("year").select("year")
    list_year[taxi_brand] = [row[0] for row in year_extract.select('year').collect()]
    # For each years of the files, compute the monthly sum of the trips
    for yr in [2015,2016] :
        for mth in range(1,13,1):
            print(yr,mth)
            date1, date2 = create_date_range(yr,mth)
            test = DF.filter(col("pickup_datetime").between(date1,date2)).select(f.mean(col("revenue")))\
                                .withColumn("avg(revenue)", f.when(col("avg(revenue)") == 0, None).otherwise(col("avg(revenue)")))\
                                .collect()
            var[taxi_brand].append([row[0] for row in test])
            maxi = max(maxi,max(var[taxi_brand])[0])
            dating[taxi_brand].append(date1+timedelta(days=14))
# Out:
# yellow
# 2015 1
# 2015 2
# 2015 3
# 2015 4
# 2015 5
# 2015 6
# 2015 7
# 2015 8
# 2015 9
# 2015 10
# 2015 11
# 2015 12
# 2016 1
# 2016 2
# 2016 3
# 2016 4
# 2016 5
# 2016 6
# 2016 7
# 2016 8
# 2016 9
# 2016 10
# 2016 11
# 2016 12
# green
# 2015 1
# 2015 2
# 2015 3
# 2015 4
# 2015 5
# 2015 6
# 2015 7
# 2015 8
# 2015 9
# 2015 10
# 2015 11
# 2015 12
# 2016 1
# 2016 2
# 2016 3
# 2016 4
# 2016 5
# 2016 6
# 2016 7
# 2016 8
# 2016 9
# 2016 10
# 2016 11
# 2016 12

# %%
# Plot the numbers of monthly number of trips 
i = -1
fig, ax = plt.subplots(1,figsize=(34,15))
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(years_fmt)
ax.xaxis.set_minor_locator(months)
for taxi_brand in ['yellow','green'] :
    i = i+1
    colors = (sorted(overlap,reverse=True))[i]
    ax.plot(dating[taxi_brand],var[taxi_brand],color=taxi_brand,label='%s taxi' %(taxi_brand),lw=3) # Line not visible, only to show values
ax.set_xlim(xmin,xmax,1)
ax.set_ylim(0,round(maxi+(maxi*0.15)))
ax.set_xlabel("Time")
ax.set_ylabel("Mean revenue by month")
ax.format_ydata = lambda x: '$%1.2f' % x
ax.grid(True)
plt.legend(ncol=4,loc=2)
fig.autofmt_xdate()

# %% [markdown]
# ## 5. What is the montlhy average trip receipt ?
#
# The average cost per in-progress-minute, which is the total amount of the trip divided by the duration of the trip. Then the monthly average of this cost is made.
#
# ##### WARNING: only Yellow and Green taxi compagnies have revenue informations.

# %%
list_taxi = [ "yellow", "green"]
list_year = {}
dating_tip = {}
var_tip = {}
maxi = 0
for taxi_brand in list_taxi :
    print(taxi_brand)
    list_year[taxi_brand] = []
    var[taxi_brand] = []
    dating[taxi_brand] = []
    # Get the list of the file for each taxi
    DF = (spark.read
                    .option("sep", ",")
                    .option("header", True)
                    .option("inferSchema", True)
                    .csv(cl_path+taxi_brand+"/*.csv") )
    # Get the date of each lines and get the list of years
    DF = DF.withColumn("trip_duration",convert_sec_to_min(f.unix_timestamp(col("dropoff_datetime"))- f.unix_timestamp(col("pickup_datetime"))))\
           .withColumn("revenue", (col("total_amount") - col("tip_amount")) / col("trip_duration"))
    DF = DF.orderBy("pickup_datetime")
    year_extract = DF.selectExpr("year(pickup_datetime) AS year", "pickup_datetime").groupBy("year").sum().orderBy("year").select("year")
    list_year[taxi_brand] = [row[0] for row in year_extract.select('year').collect()]
    # For each years of the files, compute the monthly sum of the trips
    for yr in [2015,2016] :
        for mth in range(1,13,1):
            print(yr,mth)
            date1, date2 = create_date_range(yr,mth)
            test = DF.filter(col("pickup_datetime").between(date1,date2)).select(f.mean(col("revenue")))\
                                .withColumn("avg(revenue)", f.when(col("avg(revenue)") == 0, None).otherwise(col("avg(revenue)")))\
                                .collect()
            var_tip[taxi_brand].append([row[0] for row in test])
            maxi = max(maxi,max(var[taxi_brand])[0])
            dating_tip[taxi_brand].append(date1+timedelta(days=14))
# Out:
# yellow
# 2015 1
# 2015 2
# 2015 3
# 2015 4
# 2015 5
# 2015 6
# 2015 7
# 2015 8
# 2015 9
# 2015 10
# 2015 11
# 2015 12
# 2016 1
# 2016 2
# 2016 3
# 2016 4
# 2016 5
# 2016 6
# 2016 7
# 2016 8
# 2016 9
# 2016 10
# 2016 11
# 2016 12
# green
# 2015 1
# 2015 2
# 2015 3
# 2015 4
# 2015 5
# 2015 6
# 2015 7
# 2015 8
# 2015 9
# 2015 10
# 2015 11
# 2015 12
# 2016 1
# 2016 2
# 2016 3
# 2016 4
# 2016 5
# 2016 6
# 2016 7
# 2016 8
# 2016 9
# 2016 10
# 2016 11
# 2016 12

# %%
# Plot the numbers of monthly number of trips 
i = -1
fig, ax = plt.subplots(1,figsize=(34,15))
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(years_fmt)
ax.xaxis.set_minor_locator(months)
for taxi_brand in ["yellow","green"] :
    i = i+1
    ax.plot(dating[taxi_brand],var[taxi_brand],color=taxi_brand,label='%s taxi' %(taxi_brand),lw=3) # Line not visible, only to show values
ax.set_xlim(xmin,xmax,1)
ax.set_ylim(0,round(maxi+(maxi*0.15)))
ax.set_xlabel("Time")
ax.set_ylabel("Mean cost per in-progress-minute by month")
ax.format_ydata = lambda x: '$%1.2f' % x
ax.grid(True)
plt.legend(ncol=4,loc=2)
fig.autofmt_xdate()

# %% [markdown]
# ## 6.  Which service would you hence prefer to be in as a driver ?
#
# The average tip per trip, where the average is computed over trips within the same month,
# grouped per dataset type. Each month the sum of the tip and the sum of the trip are computed. Then the tip is divided by the numbers of trips to get the average tip by trip.
#
# ##### WARNING: only Yellow and Green taxi compagnies have revenue informations.

# %%
list_taxi = [ "yellow", "green"]
list_year = {}
dating_tip = {}
var_tip = {}
maxi_tip = 0
for taxi_brand in list_taxi :
    print(taxi_brand)
    list_year[taxi_brand] = []
    var_tip[taxi_brand] = []
    dating_tip[taxi_brand] = []
    # Get the list of the file for each taxi
    DF = (spark.read
                    .option("sep", ",")
                    .option("header", True)
                    .option("inferSchema", True)
                    .csv(cl_path+taxi_brand+"/*.csv") )
    # Get the date of each lines and get the list of years
    DF = DF.orderBy("pickup_datetime")
    year_extract = DF.selectExpr("year(pickup_datetime) AS year", "pickup_datetime").groupBy("year").sum().orderBy("year").select("year")
    list_year[taxi_brand] = [row[0] for row in year_extract.select('year').collect()]
    # For each years of the files, compute the monthly sum of the trips
    for yr in [2019,2020] :
        for mth in range(1,13,1):
            print(yr,mth)
            date1, date2 = create_date_range(yr,mth)
            test = DF.filter(col("pickup_datetime").between(date1,date2)).select(f.sum(col("tip_amount"))).collect()[0]
            test2 = DF.filter(col("pickup_datetime").between(date1,date2)).select(f.count(col("pickup_datetime"))).collect()[0]
            var_tip[taxi_brand].append(test[0]/test2[0])
            print(var_tip[taxi_brand])
            #maxi = max(maxi,max(var[taxi_brand])[0])
            dating_tip[taxi_brand].append(date1+timedelta(days=14))
# Out:
# yellow
# 2019 1
# [1.8296023383862423]
# 2019 2
# [1.8296023383862423, 2.161405178136755]
# 2019 3
# [1.8296023383862423, 2.161405178136755, 2.2126708894167315]
# 2019 4
# [1.8296023383862423, 2.161405178136755, 2.2126708894167315, 2.192598408710218]
# 2019 5
# [1.8296023383862423, 2.161405178136755, 2.2126708894167315, 2.192598408710218, 2.2226860042515266]
# 2019 6
# [1.8296023383862423, 2.161405178136755, 2.2126708894167315, 2.192598408710218, 2.2226860042515266, 2.2563503103731954]
# 2019 7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-1915abb0ac6f> in <module>
#      26             test = DF.filter(col("pickup_datetime").between(date1,date2)).select(f.sum(col("tip_amount"))).collect()[0]
#      27             test2 = DF.filter(col("pickup_datetime").between(date1,date2)).select(f.count(col("pickup_datetime"))).collect()[0]
# ...

# %%
# Plot the numbers of monthly number of trips 
i = -1
fig, ax = plt.subplots(1,figsize=(34,15))
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(years_fmt)
ax.xaxis.set_minor_locator(months)
for taxi_brand in ["yellow","green"] :
    i = i+1
    ax.plot(dating[taxi_brand],var[taxi_brand],color=taxi_brand,label='%s taxi' %(taxi_brand),lw=3) # Line not visible, only to show values
ax.set_xlim(xmin,xmax,1)
ax.set_ylim(0,5)
ax.set_xlabel("Time")
ax.set_ylabel("Montlhy average tip per trip")
ax.format_ydata = lambda x: '$%1.2f' % x
ax.grid(True)
plt.legend(ncol=4,loc=2)
fig.autofmt_xdate()

# %% [markdown]
# ## 7.  Which service would you hence prefer to be in as a driver ?
#
# The median monthly average trip speed, where the median is computer over trips within the same month, grouped per dataset type and per borough.

# %%
zones = gpd.read_file('data/metadata/taxi_zones.shp')
list_zones = zones.borough.unique()

# %%
# Out:
# ['EWR' 'Queens' 'Bronx' 'Manhattan' 'Staten Island' 'Brooklyn']

# %%
list_taxi = ["yellow"]
list_year = {}
dating = {}
var = {}
maxi = 0
for taxi_brand in list_taxi :
    # Get the list of the file for each taxi
    DF = (spark.read
                    .option("sep", ",")
                    .option("header", True)
                    .option("inferSchema", True)
                    .csv(cl_path+taxi_brand+"/*.csv") )
    print(DF.printSchema())
    for zones in list_zones :
        var_name = taxi_brand+"-"+zones
        print(var_name)
        list_year[var_name] = []
        dating[var_name] = []
        var[var_name] = []
        # LocationID for the borought
        locID = get_locID_fromzone(zones_df, zones)
        select_zone = DF.where(col("pulocationid").isin(locID)).select(col("pickup_datetime"), col("dropoff_datetime"), col("trip_distance") )
        # Add column trip duration and trip spid
        select_zone = select_zone.withColumn("trip_duration",(f.unix_timestamp(col("dropoff_datetime"))- f.unix_timestamp(col("pickup_datetime"))))\
               .withColumn("trip_speed", ( col("trip_distance") / col("trip_duration")))
        # Get the date of each lines and get the list of years
        select_zone = select_zone.orderBy("pickup_datetime")
        year_extract = select_zone.selectExpr("year(pickup_datetime) AS year", "pickup_datetime").groupBy("year").sum().orderBy("year").select("year")
        list_year[var_name] = [row[0] for row in year_extract.select('year').collect()]
        # For each years of the files, compute the monthly sum of the trips
        for yr in list_year[var_name] :
            for mth in range(1,13,1):
                date1, date2 = create_date_range(yr,mth)
                test = select_zone.filter(col("pickup_datetime").between(date1,date2))\
                                        .select(f.mean(col("trip_speed")))\
                                        .withColumn("avg(trip_speed)", f.when(col("avg(trip_speed)") == 0, None).otherwise(col("avg(trip_speed)")))\
                                        .collect()
                var[var_name].append([row[0] for row in test])
                #maxi = max(maxi,max(var[taxi_brand])[0])
                dating[var_name].append(date1+timedelta(days=14))
                print(yr,mth)
# Out:
# root
#  |-- vendorid: string (nullable = true)
#  |-- pickup_datetime: string (nullable = true)
#  |-- dropoff_datetime: string (nullable = true)
#  |-- passenger_count: string (nullable = true)
#  |-- trip_distance: string (nullable = true)
#  |-- ratecodeid: string (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PUlocationid: string (nullable = true)
#  |-- DOlocationid: string (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- fare_amount: string (nullable = true)
#  |-- extra: string (nullable = true)
#  |-- mta_tax: string (nullable = true)
#  |-- tip_amount: string (nullable = true)
#  |-- tolls_amount: string (nullable = true)
#  |-- improvement_surcharge: string (nullable = true)
#  |-- total_amount: string (nullable = true)
#  |-- congestion_surcharge: string (nullable = true)
#
# None
# yellow-EWR
# 2009 1
# 2009 2
# 2009 3
# 2009 4
# 2009 5
# 2009 6
# 2009 7
# 2009 8
# 2009 9
# 2009 10
# 2009 11
# 2009 12
# 2010 1
# 2010 2
# ...

# %%
# Plot the numbers of monthly number of trips 
i = -1
fig, ax = plt.subplots(1,figsize=(34,15))
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(years_fmt)
ax.xaxis.set_minor_locator(months)
zones="Manhattan"
for taxi_brand in ["yellow"] :
    var_name = taxi_brand+"-"+zones
    i = i+1
    ax.plot(dating[var_name],var[var_name],color=taxi_brand,label='%s taxi' %(taxi_brand),lw=3) # Line not visible, only to show values
ax.set_xlim(xmin,xmax,1)
ax.set_ylim(0,0.1)
ax.set_xlabel("Time")
ax.set_ylabel("Montlhy average tip per trip")
ax.format_ydata = lambda x: '$%1.2f' % x
ax.grid(True)
plt.legend(ncol=4,loc=2)
fig.autofmt_xdate()

# %% [markdown]
# ## 8.  How long does it take to get to a New York City Airport?
#
# New York City has 3 airport: Newark Airport (zone 1) , JFK Airport (zone 123), and LaGuardia Airport (zones 132, 138).
# Assume that the trip to the airport starts in:
# - Manhattan Midtown (zones 161-164)
# - Chelsea (zones 68, 246)
# - Times Squeare (zone 230)
# - Garment District (zone 100).
#
# 1- Extract
# This query can be answered from dierent per-
# spectives. First, compute the median travel time from Manhattan Midtown to the airport
# under consideration, binned per departure time (e.g., departure between midnight and 1h,
# between 1h and 2h, ...). Here the median is computed over all trips. Plot the results, per
# airport. What is the best timeslot to depart to the airport? What is the worst timeslot?
# For the best and worst timeslots, also compute how the monthly median travel time has
# evolved over the past years.

# %%
from pyspark.sql.types import StringType, DateType, IntegerType, BooleanType, TimestampType, FloatType, DoubleType
from pyspark.sql.types import LongType, StringType, StructType, StructField

# Load the shapefile, this yields a GeoDataFrame that has a row for each zone
zones = gpd.read_file('data/metadata/taxi_zones.shp')
zones_df = spark.createDataFrame(zones).cache()

New_AP = [1]
JFK_AP = [123]
LG_AP = [132, 138]
zones_manath = [161, 162,163,164]
taxi_brand = "yellow"
var = {}
dating = {}
yellow_DF = (spark.read
                    .option("sep", ",")
                    .option("header", True)
                    .option("inferSchema", True)
                    .csv(cl_path+taxi_brand+"/*.csv") )
yellow_DF = yellow_DF.withColumn("PULocationID",yellow_DF["PULocationID"].cast(IntegerType()))\
                 .withColumn("DOLocationID",yellow_DF["DOLocationID"].cast(IntegerType()))\
                 .withColumn("pickup_datetime",yellow_DF["pickup_datetime"].cast(TimestampType()))\
                 .withColumn("dropoff_datetime",yellow_DF["dropoff_datetime"].cast(TimestampType()))\
                 .withColumn("passenger_count",yellow_DF["passenger_count"].cast(DoubleType()))\
                 .withColumn("trip_distance",yellow_DF["trip_distance"].cast(DoubleType()))\
                 .withColumn("tip_amount",yellow_DF["tip_amount"].cast(DoubleType()))\
                 .withColumn("total_amount",yellow_DF["total_amount"].cast(DoubleType()))
print(DF.printSchema())
#locID_Manhattan = get_locID_fromzone(zones_df, zones)
select_zone = yellow_DF.where((col("PULocationID").isin(zones_manath)) & (col("DOLocationID").isin(New_AP)))\
                .select(col("pickup_datetime"), col("dropoff_datetime"), col("trip_distance"))\
                .withColumn("trip_duration",(f.unix_timestamp(col("dropoff_datetime"))- f.unix_timestamp(col("pickup_datetime"))))
select_zone = select_zone.orderBy("pickup_datetime")
year_extract = select_zone.selectExpr("year(pickup_datetime) AS year", "pickup_datetime").groupBy("year").sum().orderBy("year").select("year")
list_year = [row[0] for row in year_extract.select('year').collect()]
# For each years of the files, compute the monthly sum of the trips
for yr in list_year :
    var[yr] = []
    dating[yr] = []
    date1=pd.to_datetime('%s-01-01 00:00:00' %(yr))
    date2 = pd.to_datetime('%s-12-31 00:00:00' %(yr))
    test_yr = select_zone.filter(col("pickup_datetime").between(date1,date2))
    test = test_yr.groupBy(hour("pickup_datetime").alias("hour")).mean("trip_duration").alias("mean").orderBy("hour")
    var[yr].append([row[0] for row in test.select("mean.avg(trip_duration)").collect()])
    dating[yr].append([row[0] for row in test.select("hour").collect()])
    print(yr,var[yr])
# Out:
# root
#  |-- pickup_datetime: timestamp (nullable = true)
#  |-- dropoff_datetime: timestamp (nullable = true)
#  |-- passenger_count: double (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#
# None
# 2009 [[600.0]]
# 2014 [[2115.0]]
# 2016 [[1977.0, 1839.6666666666667, 1634.0, 1904.5, 2730.0, 2226.8, 2203.0, 2200.0, 1975.0, 2198.0, 2739.3333333333335, 3061.75, 3769.5, 4229.0, 3420.0]]
# 2017 [[1535.0, 1850.142857142857, 2098.714285714286, 2262.285714285714, 2918.0, 2525.0, 2291.0, 2210.285714285714, 2991.6666666666665, 8724.615384615385, 2943.2727272727275, 3159.0, 3834.0, 4181.0, 2955.0, 2375.5, 86282.0]]
# ...

# %%
print(list_year)
# Out:
# []

# %%
var.append([row[0] for row in test.select("sum(trip_duration)").collect()])
dating.append([row[0] for row in test.select("hour").collect()])

# %%
i = -1
parameters = {'axes.labelsize': 25,
          'axes.titlesize': 35,
          'legend.fontsize': 20,
          'xtick.labelsize': 20,
          'ytick.labelsize':20}
plt.rcParams.update(parameters)
fig, ax = plt.subplots(1,figsize=(15,7))
for yr in [2016,2018,2019] :
    i = i+4
    colors = (sorted(overlap,reverse=True))[i]
    to_min = [ var[yr][0][i]/60 for i in range(0,len(var[yr][0])) ]
    ax.plot(dating[yr][0],to_min,color=colors,label='%s' %(yr),lw=3) # Line not visible, only to show values
ax.set_xlim(0,24,1)
ax.set_ylim(20,120)
ax.set_xlabel("Time binned by hour")
plt.title("Trip duration from Manathann to Newark Airport", fontsize=30)
ax.set_ylabel("Duration in min")
ax.format_ydata = lambda x: '$%1.2f' % x
ax.grid(True)
plt.legend(ncol=4,loc=2)
fig.autofmt_xdate()
plt.savefig(cl_path+"../Plot_Q8_Man2Newark_Yell-Gre.png", bbox_inches = 'tight', pad_inches=0)

# %%
len(var[yr][0])
to_min = [ convert_sec_to_min(np.round(var[yr][0][i])) for i in range(0,len(var[yr][0])) ]
#convert_sec_to_min(var[yr][0])
print(to_min)
print(np.round(var[yr][0]))

np.round(var[yr][0])
# Out:
# [32.21666666666667, 31.016666666666666, 28.266666666666666, 33.35, 40.233333333333334, 45.71666666666667, 42.3, 42.4, 40.18333333333333, 43.416666666666664, 46.55, 48.96666666666667, 11.116666666666667, 2.1333333333333333, 5.5, 52.53333333333333, 42.46666666666667]
# [1933. 1861. 1696. 2001. 2414. 2743. 2538. 2544. 2411. 2605. 2793. 2938.
#  4267. 3728. 3930. 3152. 2548.]
# array([1933., 1861., 1696., 2001., 2414., 2743., 2538., 2544., 2411.,
#        2605., 2793., 2938., 4267., 3728., 3930., 3152., 2548.])

# %%
date1=pd.to_datetime('%s-01-01 00:00:00' %(yr))
date1+timedelta(mth=12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-299-f32c59034294> in <module>
#       1 date1=pd.to_datetime('%s-01-01 00:00:00' %(yr))
# ----> 2 date1+timedelta(mth=12)
#
# TypeError: 'mth' is an invalid keyword argument for __new__()

# %%
convert_sec_to_min(2548)
# Out:
# 42.46666666666667
